# %%
import numpy as np
def read_latency(d, f):
    with open(d + 'trace.' + f, 'r') as fin:
        line = fin.readline()
        trace_latency_list = np.array(line.split(), dtype=np.float32)
    with open(d + 'e2e.' +f, 'r') as fin:
        line = fin.readline()
        e2e_latency_list = np.array(line.split(), dtype=np.float32)
    return trace_latency_list, e2e_latency_list

# %%
FONT_SIZE = 24
plt.rc('font', size=FONT_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=FONT_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=FONT_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=FONT_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=FONT_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=FONT_SIZE)    # legend fontsize
plt.rc('figure', titlesize=FONT_SIZE)  # fontsize of the figure title
plt.rc('lines', linewidth=3)
plt.rc('lines', markersize=12)  # size of marker

# %%
t1, e1 = read_latency('1682240776') #EC-ine
t2, e2 = read_latency('1682240793') #EC
t3, e3 = read_latency('1682240802') #LRU
len1 = len(t1)
len2 = len(t2)
len_min = min(len1, len2)
#t1 = t1[:len_min]
#t2 = t2[:len_min]

# %%
t1, e1 = read_latency('1682373127') #EC-ine
t2, e2 = read_latency('1682372929') #EC
t3, e3 = read_latency('1682312148') #LRU 4096
len1 = len(t1)
len2 = len(t2)
len_min = min(len1, len2)
#t1 = t1[:len_min]
#t2 = t2[:len_min]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-24-9d889af71669> in <module>
#       1 t1, e1 = read_latency('1682373127') #EC-ine
#       2 t2, e2 = read_latency('1682372929') #EC
# ----> 3 t3, e3 = read_latency('1682312148') #LRU 4096
#       4 len1 = len(t1)
#       5 len2 = len(t2)
#
# <ipython-input-13-7349b361f1f3> in read_latency(f)
#       1 import numpy as np
#       2 def read_latency(f):
# ----> 3     with open('/nfs/latency2/trace.'+ f, 'r') as fin:
#       4         line = fin.readline()
#       5         trace_latency_list = np.array(line.split(), dtype=np.float32)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/nfs/latency2/trace.1682312148'

# %%
d = '/nfs/latency_1024/'
t1, e1 = read_latency(d, '1682302221') #EC-ine
t2, e2 = read_latency(d, '1682302233') #EC
t3, e3 = read_latency(d, '1682302247') #LRU 1024
len1 = len(t1)
len2 = len(t2)
len_min = min(len1, len2)
#t1 = t1[:len_min]
#t2 = t2[:len_min]

# %%
t1, e1 = read_latency('1682358527') #EC-ine
t2, e2 = read_latency('1682358517') #EC
t3, e3 = read_latency('1682358536') #LRU 1024
len1 = len(t1)
len2 = len(t2)
len_min = min(len1, len2)
#t1 = t1[:len_min]
#t2 = t2[:len_min]

# %%
t_ine = t1[50000000:]
t_mat = t2[50000000:]
t_lru = t3[50000000:]
e_ine = e1[50000000:]
e_mat = e2[50000000:]
e_lru = e3[50000000:]
print('avg replay latency (MAT inelastic - LRU) ', np.mean(t_ine-t_lru), ' us')
print('avg replay latency (MAT - LRU)           ', np.mean(t_mat-t_lru), ' us')
print('avg cache latency (MAT inelastic - LRU)  ', np.mean(e_ine-e_lru), ' us')
print('avg cache latency (MAT - LRU)            ',np.mean(e_mat-e_lru), ' us')
print(len(t_ine))
# Out:
# avg replay latency (MAT inelastic - LRU)  107.38725  us
# avg replay latency (MAT - LRU)            4.8000636  us
# avg cache latency (MAT inelastic - LRU)   14.631653  us
# avg cache latency (MAT - LRU)             5.146421  us
# 110000000

# %%
t_mat_sort = np.sort(t_mat)
t_ine_sort = np.sort(t_ine)
t_lru_sort = np.sort(t_lru)
print('done')
# Out:
# done

# %%
import matplotlib.pyplot as plt

for n_tail in (0, 1000000):
    plt.figure(figsize=(5,4))
    diff_t = t_mat-t_lru
    x = np.sort(diff_t)[-n_tail:]
    y = np.arange(len(x))/float(len(x))
    plt.plot(x, y, label='MAT')
    plt.xscale('symlog')

    diff_t = t_ine-t_lru
    x = np.sort(diff_t)[-n_tail:]
    y = np.arange(len(x))/float(len(x))
    plt.plot(x, y, label='MAT inelastic')
    plt.xscale('symlog')
    if n_tail == 0:
        plt.xticks([-1000000, -1000, 0, 1000, 1000000], rotation=0)
    plt.xlabel('Replay Latency vs. LRU (us)', fontsize=28)
    plt.ylabel('CDF', fontsize=28)
    plt.legend(ncol=1, prop={'size': 20}, loc='lower right')

    plt.show()

# %%
import matplotlib.pyplot as plt

for n_tail in (0, 1000000):
    plt.figure(figsize=(6,5))
    x = t_ine_sort[-n_tail:]
    #plt.ylim(top=0.99999)
    #plt.ylim(bottom=0.1)
    y = np.arange(len(x))/float(len(x))
    plt.plot(x, y, label='MAT inelastic')
    #plt.yscale('log')
    plt.xscale('log')
    x = t_mat_sort[-n_tail:]
    y = np.arange(len(x))/float(len(x))
    plt.plot(x, y, label='MAT')
    plt.xscale('log')
    x = t_lru_sort[-n_tail:]
    y = np.arange(len(x))/float(len(x))
    plt.plot(x, y, label='LRU')

    plt.xscale('log')
    plt.xlabel('Replay Latency (us)', fontsize=34)
    plt.ylabel('CDF', fontsize=34)
    plt.legend(ncol=1, prop={'size': 24}, loc='lower right')

    plt.show()

# %%
e_mat_sort = np.sort(e2)
e_ine_sort = np.sort(e1)
e_lru_sort = np.sort(e_lru)
print('done')
# Out:
# done

# %%
for n_tail in (0, 1000000):
    plt.figure(figsize=(5,4))
    diff_t = e_mat-e_lru
    x = np.sort(diff_t)[-n_tail:]
    y = np.arange(len(x))/float(len(x))
    plt.plot(x, y, label='MAT')
    plt.xscale('symlog')

    diff_t = e_ine-e_lru
    x = np.sort(diff_t)[-n_tail:]
    y = np.arange(len(x))/float(len(x))
    plt.plot(x, y, label='MAT inelastic')
    plt.xscale('symlog')
    if n_tail == 0:
        plt.xticks([-1000000, -1000, 0, 1000, 1000000], rotation=0)
    plt.xlabel('Cache Latency vs. LRU (us)', fontsize=28)
    plt.ylabel('CDF', fontsize=28)
    plt.legend(ncol=1, prop={'size': 20}, loc='lower right')

    plt.show()

# %%
for n_tail in (1000000, 0):
    plt.figure(figsize=(5,4))
    x = e_ine_sort[-n_tail:]
    y = np.arange(len(x))/float(len(x))
    plt.plot(x, y, label='MAT inelastic')
    plt.xscale('log')
    x = e_mat_sort[-n_tail:]
    y = np.arange(len(x))/float(len(x))
    plt.plot(x, y, label='MAT')
    plt.xscale('log')
    x = e_lru_sort[-n_tail:]
    y = np.arange(len(x))/float(len(x))
    plt.plot(x, y, label='LRU')

    plt.xscale('log')
    plt.xlabel('Cache Latency (us)', fontsize=28)
    plt.ylabel('CDF', fontsize=28)
    plt.legend(ncol=1, prop={'size': 20}, loc='lower right')

    plt.show()

# %%
import numpy as np
def read_miss(f):
    miss_list = []
    with open(f, 'r') as fin:
        lines = fin.readlines()
        for line in lines:
            if line.startswith('miss ratio:'):
                miss_list.append(line.split()[-1])
    return np.array(miss_list, dtype=np.float32)

# %%
ec_miss = read_miss('/nfs/latency2/ec.10')
print(len(ec_miss))
eci_miss = read_miss('/nfs/latency2/ec_i.10')
print(len(eci_miss))
lru_miss = read_miss('/nfs/latency2/lru.10')
print(len(lru_miss))
# Out:
# 1990
# 1990
# 1990

# %%
plt.figure(figsize=(12,6))
n = 5
a1 = np.average(lru_miss.reshape(-1, n), axis=1)
a2 = np.average(eci_miss.reshape(-1, n), axis=1)
plt.plot(range(len(a1)), a1, label='LRU')
plt.plot(range(len(a2)), a2, label='ECi')


plt.xlabel('time', fontsize=34)
plt.ylabel('Miss ratio (%)', fontsize=34)
plt.legend(ncol=1, prop={'size': 24}, loc='lower right')

# %%
ec_miss_sort = np.sort(ec_miss[500:1900])
eci_miss_sort = np.sort(eci_miss[500:1900])
lru_miss_sort = np.sort(lru_miss[500:1900])
plt.figure(figsize=(5,4))
x = ec_miss_sort
y = np.arange(len(x))/float(len(x))
plt.plot(x, y, label='MAT')
x = eci_miss_sort
y = np.arange(len(x))/float(len(x))
plt.plot(x, y, label='MAT inelastic')
x = lru_miss_sort
y = np.arange(len(x))/float(len(x))
plt.plot(x, y, label='LRU')

plt.xlabel('Miss ratio (%)', fontsize=34)
plt.ylabel('CDF', fontsize=34)
plt.legend(ncol=1, prop={'size': 24}, loc='lower right')

plt.show()
